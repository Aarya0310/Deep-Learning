# %% [markdown]
# <a href="https://colab.research.google.com/github/jawanjalaarya/Deep-Learning/blob/main/linear_regression_error_metrics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 23070521003 - Aarya Bhende

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error

X = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)
y = np.array([20, 40, 50, 65, 80])

model = LinearRegression()
model.fit(X, y)

slope = model.coef_[0]
intercept = model.intercept_

y_pred = model.predict(X)

mae = mean_absolute_error(y, y_pred)
mse = mean_squared_error(y, y_pred)
rmse = np.sqrt(mse)

print("--- Regression Line ---")
print("Predicted y values:", y_pred)
print(f"Equation: y = {slope:.1f}x + {intercept:.1f}")
print(f"Slope (m): {slope:.1f}")
print(f"Intercept (c): {intercept:.1f}\n")

print("--- Error Metrics ---")
print(f"MAE:  {mae:.2f}")
print(f"MSE:  {mse:.2f}")
print(f"RMSE: {rmse:.4f}")
# Out:
# --- Regression Line ---
# Predicted y values: [22.  36.5 51.  65.5 80. ]
# Equation: y = 14.5x + 7.5
# Slope (m): 14.5
# Intercept (c): 7.5
#
# --- Error Metrics ---
# MAE:  1.40
# MSE:  3.50
# RMSE: 1.8708
